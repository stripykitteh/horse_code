# %%
# Assert minimum versions 
import sys 
assert sys.version_info >= (3, 5) 
import sklearn 
assert sklearn.__version__ >= "0.20" 
 
# Import packages and modules that will be used 
import numpy as np 
import pandas as pd
from sklearn import linear_model
from sklearn import metrics 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import SGDClassifier 
from sklearn.metrics import accuracy_score 

# Import and configure matplotlib 
# %matplotlib inline  
import matplotlib as mpl  
import matplotlib.pyplot as plt 
mpl.rc('figure', dpi=120) # set good resolution

# Set a seed for reproducability
import random
random.seed(42)
# numpy needs a random seed, too
np.random.seed(42)

import datetime
from datetime import date

# %%
df = pd.read_csv('/Users/phillipmonk/research_paper/horse_code/data/horse_data.csv')

# %%
df.head()
# Out:
#     horse_name      foaled          colour      sire            dam      sex  \
# 0  A Good Yarn  18/09/2013  Brown or Black  O'lonhro  Little Thread  Gelding
# 1  A Good Yarn  18/09/2013  Brown or Black  O'lonhro  Little Thread  Gelding
# 2  A Good Yarn  18/09/2013  Brown or Black  O'lonhro  Little Thread  Gelding
# 3  A Good Yarn  18/09/2013  Brown or Black  O'lonhro  Little Thread  Gelding
# 4  A Good Yarn  18/09/2013  Brown or Black  O'lonhro  Little Thread  Gelding
#
#    group_1_wins  starts  firsts  seconds  ...      date  dist cond weight  \
# 0             0      46       6        8  ...  31/07/23  1100  9.0   61.5
# 1             0      46       6        8  ...  02/01/23  1125  3.0   54.0
# 2             0      46       6        8  ...  16/12/22  1109  3.0   61.5
# 3             0      46       6        8  ...  08/12/22  1100  3.0   58.5
# 4             0      46       6        8  ...  27/11/22  1000  4.0   56.5
#
#    800m  400m margin rating  odds odds_source
# 0   2.0   1.0   10.2     61  20.0          SP
# 1   7.0   5.0    6.7     61  11.0          SP
# 2   6.0   6.0    0.8     61   6.5          SP
# 3   4.0   5.0    1.0     61   9.5          SP
# 4  11.0  10.0    5.6     63  15.0          SP
#
# [5 rows x 40 columns]

# %%
df['date'] = pd.to_datetime(df['date'], format='%d/%m/%y').dt.date

# %%
df_jockey = df[df['track'].isin(['CAUL','FLEM','RAND','RHIL'])]['jockey'].unique()

df_jockey
# Out:
# array(['jarrod-fry', 'luke-nolen', 'luke-campbell', 'ben-melham',
#        'patrick-moloney', 'craig-newitt', 'craig-williams',
#        'jason-collett', 'kerrin-mcevoy', 'jamie-mott', 'thomas-stockdale',
#        'cejay-graham', 'jamie-kah', 'william-pike', 'ethan-brown',
#        'amy-mclucas', 'reece-jones', 'michael-dee', 'linda-meech',
#        'brett-prebble', 'john-allen', 'regan-bayliss', 'hugh-bowman-hk',
#        'jye-mcneil', 'andrew-gibbons', 'dylan-gibbons', 'tahlia-hope',
#        'daniel-moor', 'carleen-hefel', 'joe-bowditch', 'damien-oliver',
#        'rachel-king', 'blake-shinn', 'teo-nugent', 'luke-currie',
#        'beau-mertens', 'chad-schofield', 'tyler-schiller',
#        'ellen-hennessy', 'james-mcdonald', 'tim-clark', 'keagan-latham',
#        'jenny-duggan', 'tom-sherry', 'luke-rolls', 'damien-thornton',
#        'jess-taylor', 'nash-rawiller', 'alysha-collett', 'louise-day',
#        'robbie-dolan', 'matthew-cartwright', 'tommy-berry', 'zac-lloyd',
#        'brock-ryan', 'glen-boss', 'aaron-bullock', 'jack-hill',
#        'jasper-franklin', 'hannah-williams', 'jordan-mallyon', 'jay-ford',
#        'koby-jennings', 'sam-clipperton', 'harry-coffey', 'fred-kersley',
#        'jean-van-overmeire', 'alana-kelly', 'harry-grace', 'lachlan-king',
#        'jordan-childs', 'michael-poy', 'daniel-stackhouse', 'james-orman',
#        'brenton-avdulla', 'william-buick-gb', 'joao-moreira-brz',
#        'julia-presits', 'damian-lane', 'wiremu-pinn', 'declan-bates',
#        'billy-egan', 'chris-williams', 'will-price', 'blaike-mcdougall',
#        'ryan-maloney', 'glyn-schofield', 'josh-richards', 'zac-spain',
#        'daniel-ganderton', 'ben-allen', 'mitchell-bell', 'andrew-adkins',
#        'joshua-parr', 'madison-lloyd', 'dean-yendall', 'kathy-ohara',
#        'grant-buckley', 'celine-gaudray', 'lachlan-neindorf',
#        'zac-purton-hk', 'jake-noonan', 'mark-zahra', 'danny-beasley',
#        'nick-heywood', 'madi-derrick', 'tatum-bull', 'ashley-morgan',
#        'dean-holland', 'gary-lo', 'mitchell-aitken', 'jeff-penza',
#        'benoit-de-la-sayette-1', 'adam-hyeronimus', 'logan-mcneil',
#        'bailey-wheeler', 'lewis-german', 'tom-marquand-gb',
#        'winona-costin', 'christine-puls', 'christian-reith',
#        'taylor-marshall', 'lee-magorrian', 'michael-walker',
#        'neil-farley', 'patrick-scorse', 'brandon-lerena', 'jett-stanley',
#        'mikayla-weir', 'ben-looker', 'serg-lisnyy', 'ben-coen',
#        'barend-vorster', 'laura-lafferty', 'brendon-mccoull',
#        'will-gordon-nz-1', 'hannah-edgley', 'brooke-stower',
#        'dom-tourneur', 'craig-robertson', 'jason-maskiell',
#        'michael-rodd', 'anthony-cavallo', 'benjamin-osmond',
#        'william-stanley', 'james-innes-jnr', 'ben-thompson',
#        'frankie-dettori-gb', 'robert-thompson', 'suraj-narredu-ind',
#        'brodie-loy', 'rory-hutchings', 'opie-bosson-nz', 'dylan-turner',
#        'ben-price', 'jamie-powell-1', 'callan-murray', 'kody-nestor',
#        'kyle-wilson-taylor', 'zac-wadick', 'robbie-downey',
#        'brad-rawiller', 'ronald-simpson', 'liam-riordan', 'rhys-mcleod',
#        'madeline-owen', 'melissa-julius', 'arron-lynch', 'anna-roper',
#        'tayla-childs', 'quayde-krogh', 'molly-bourke', 'michael-heagney',
#        'ryan-moore-gb', 'stephen-baster', 'jim-byrne', 'ryan-houston',
#        'madeleine-wishart', 'clayton-gallagher', 'heavelon-van-der-hoven',
#        'jacob-opperman', 'emily-finnegan', 'andrew-mallyon',
#        'brandon-griffiths', 'samantha-clenton', 'jason-holder',
#        'nathan-punch', 'kacie-adams', 'tom-madden', 'brian-higgins',
#        'billy-owen', 'chris-parnham', 'jake-toeroek',
#        'georgina-mcdonnell', 'randy-tan', 'anthony-darmanin',
#        'kayla-nisbet', 'mathew-cahill', 'robyn-freeman',
#        'jamie-spencer-gb', 'sheridan-clarke', 'chloe-azzopardi',
#        'shirley-hunter', 'brian-park', 'troy-turner', 'jack-martin',
#        'jon-grisedale', 'clayton-douglas', 'jason-lyon', 'bradley-vale',
#        'beany-panya', 'hannah-le-blanc', 'blake-spriggs',
#        'ashleigh-stanley', 'darryl-mclellan', 'tom-prebble',
#        'kiran-quilty', 'chris-obrien', 'jeff-kehoe', 'sam-weatherley-nz',
#        'noel-callow', 'robbie-brewer', 'luke-ferraris-chn', 'sigrid-carr',
#        'dwayne-dunn', 'georgia-dobie-1', 'lachlan-overall',
#        'shaun-mcgruddy', 'jake-pracey-holmes', 'chris-symons',
#        'shaun-guymer', 'simon-miller', 'ron-stewart', 'mikaela-lawrence',
#        'adam-mccabe', 'codi-jordan', 'brendan-ward', 'qin-yong',
#        'campbell-rawiller', 'jason-benbow', 'braith-nock',
#        'matthew-chadwick', 'nozi-tomizawa', 'jag-guthmann-chester',
#        'luke-dittman', 'matthew-palmer', 'peter-graham', 'lucinda-boyd',
#        'martin-harley', 'alexandra-bryan', 'amy-herrmann', 'brad-stewart'],
#       dtype=object)

# %%
pd.DataFrame(df_jockey).to_csv('/Users/phillipmonk/research_paper/horse_code/data/jockeys.csv')

# %%
df_trainer = df[(df['date'] >= datetime.date(2022,1,1)) & (df['track'].isin(['CAUL','FLEM','RAND','RHIL']))]['trainer'].unique()

df_trainer
# Out:
# array(['mervyn-mckenzie', 'dean-krongold', 'robbie-griffiths',
#        'andrew-homann', 'chris-waller', 'ben-hayes', 'john-sprague',
#        'james-cummings', 'gregory-mcfarlane', 'mick-price',
#        'matthew-dale', 'kerry-parker', 'kristen-buchanan',
#        'aaron-purcell', 'ciaron-maher', 'roger-james-nz', 'paul-snowden',
#        'trent-busuttin', 'kris-lees', 'mitchell-freedman',
#        'bruce-anderson', 'tony-mcevoy', 'david-payne',
#        'gai-waterhouse-ao', 'mick-cerchi', 'leon-corstens',
#        'andrew-forsman-nz', 'chris-bieg', 'annabel-neasham', 'bryce-heys',
#        'marc-quinn', 'will-clarken', 'john-macmillan', 'shane-fliedner',
#        'jason-coyle', 'sam-kavanagh', 'matt-laurie', 'terry-robinson',
#        'john-hawkes', 'richard-jolly', 'bjorn-baker', 'paul-messara',
#        'gary-portelli', 'robert-hickmott', 'tash-burleigh',
#        'richard-freedman', 'michael-freedman', 'paul-koumis',
#        'michael-moroney', 'anthony-cummings', 'robert-quinn',
#        'mark-kavanagh', 'imogen-miller', 'jarrod-robinson',
#        'patrick-payne', 'andrew-noblet', 'luke-price', 'les-bridge',
#        'peter-g-moody', 'danielle-seib', 'mathew-ellerton',
#        'barry-campbell', 'mike-cattell', 'rob-wellington',
#        'patrick-kearney', 'phillip-stokes', 'william-freedman',
#        'john-sadler', 'gregory-hickman', 'mack-griffith', 'trevor-rogers',
#        'joseph-pride', 'garry-frazer', 'lindsey-smith',
#        'stephen-marsh-nz', 'shane-nichols', 'scott-aspery', 'gary-colvin',
#        'andrew-bobbin', 'shawn-mathrick', 'brett-thompson', 'ken-keys',
#        'matthew-smith', 'brent-stanley', 'wayne-seelin', 'ben-lees',
#        'dean-binaisse', 'craig-weeding', 'caroline-jennings',
#        'anthony-freedman', 'dean-mirfin', 'jean-dubois', 'peter-lafferty',
#        'edward-cummings', 'symon-wilde', 'henry-dwyer', 'ken-elford',
#        'blake-fitzpatrick', 'kim-waugh', 'paul-perry', 'cameron-crockett',
#        'andrew-scott', 'mick-bell', 'john-oshea', 'danny-obrien',
#        'danny-williams', 'daniel-bowman', 'ben-brisbourne', 'sara-ryan',
#        'kylie-gavenlock', 'simon-zahra', 'brad-widdup', 'john-thompson',
#        'richard-litt', 'jody-thompson', 'ian-finn', 'sarah-murray-leslie',
#        'natalie-jarvis', 'jason-deamer', 'cody-morgan', 'lee-curtis',
#        'john-mcardle', 'cindy-alderson', 'tom-dabernig', 'kevin-corstens',
#        'jessie-constantine', 'ron-stubbs', 'michael-kent', 'tony-gollan',
#        'gerald-ryan', 'kelly-purdy', 'lyle-chandler', 'richard-laming',
#        'jerome-hunter', 'shayne-fisher', 'damien-lane', 'john-ramsey',
#        'daryl-archard', 'joseph-obrien-ire', 'tracey-bartley',
#        'brett-cavanough', 'john-sargent', 'darren-graham',
#        'clinton-mcdonald', 'saab-hasan', 'ron-quinton', 'troy-oneile',
#        'jeremy-gask', 'benjamin-smith', 'steven-pateman', 'nick-ryan',
#        'adam-trinder', 'david-feek', 'jason-warren', 'greg-eurell',
#        'dan-osullivan', 'emma-lee-browne', 'claire-lever', 'lee-hope',
#        'jane-clement', 'robert-agnew', 'adam-duggan', 'greg-middleton',
#        'peter-gelagotis', 'simon-ryan', 'geoff-duryea', 'michael-travers',
#        'marc-conners', 'john-pascoe', 'enver-jusufovic', 'jamie-edwards',
#        'trevor-j-andrews', 'matt-cumani', 'allan-mcrae', 'matthew-seyers',
#        'aaron-clarke', 'brett-robb', 'rodney-northam', 'jan-bowen',
#        'gavin-bedggood', 'archie-alexander', 'paul-cave', 'paul-preusker',
#        'alison-smith', 'grahame-begg', 'peter-maher', 'terry-croft',
#        'scott-singleton', 'ivan-lister', 'mark-newnham', 'sue-grills',
#        'ross-mcconville', 'gwenda-markwell', 'peter-j-morgan',
#        'james-ponsonby', 'michael-huglin', 'melody-cunningham',
#        'nigel-blackiston', 'shea-eden', 'david-jolly', 'mark-walker-nz',
#        'steven-odea', 'patrick-caboche', 'garry-lunn', 'john-moloney',
#        'brett-lazzarini', 'aleacia-bennett', 'yoshitomo-shima',
#        'matthew-dunn', 'craig-carmody', 'martin-gray', 'darryl-karp',
#        'jamie-scott', 'luke-oliver', 'bob-milligan', 'wayne-wilkes',
#        'gayna-williams', 'nathan-doyle', 'alex-rae', 'clayton-douglas',
#        'clarry-conners', 'troy-corstens', 'damien-smith', 'pat-carey',
#        'jeremy-sylvester', 'tim-donnelly', 'clay-beasy', 'arthur-pace',
#        'julius-sandhu', 'dwayne-reid', 'jim-lee', 'cheryl-weller',
#        'david-atkins', 'maddie-raymond', 'nathan-dunn', 'jack-laing',
#        'richard-cully', 'monica-croston', 'julie-richards', 'blake-ryan',
#        'paul-murray', 'joseph-ible', 'luke-thomas', 'david-bourne',
#        'lyn-tolson', 'robert-pearse', 'stephen-jones', 'genevieve-browne',
#        'stephen-meyer', 'paul-shailer', 'allan-kehoe', 'kathryn-durden',
#        'tony-noonan', 'james-ferguson', 'tony-ball', 'anthony-chibnall',
#        'connie-greig', 'peter-robl', 'angela-davies', 'adam-campton',
#        'christine-sexton', 'paul-niceforo', 'mark-c-webb',
#        'matthew-brown', 'norm-gardner', 'geoff-obrien', 'gareth-andrews',
#        'lloyd-kennewell', 'theresa-bateup', 'marco-botti-gb',
#        'ashlee-grives', 'john-steinmetz', 'lance-osullivan',
#        'alisa-hinch', 'mark-minervini', 'william-haggas-gb',
#        'david-brideoake', 'craig-widdison', 'keith-dryden',
#        'craig-thornton', 'liam-howley', 'robbie-laing', 'pat-murphy',
#        'jacob-perrett', 'jenny-graham', 'david-pfieffer', 'levi-kavanagh',
#        'desleigh-forster', 'nikki-burke', 'dale-short', 'david-mccolm',
#        'sue-murphy', 'gary-nickson', 'john-leek-jnr',
#        'patrick-f-ryan-jnr', 'helen-white', 'chris-calthorpe',
#        'mark-stewart', 'rodney-bailey', 'scott-brunton', 'kylie-vella',
#        'michael-ryan', 'damien-moyle', 'norman-rogers', 'jackson-pallot',
#        'mitchell-beer', 'kasey-keys', 'jackie-beriman', 'amy-yargi',
#        'lynne-morrison', 'michael-shepherdson', 'peter-graham',
#        'jake-hull', 'mark-pegus', 'daniel-williams', 'jon-oconnor',
#        'cody-reardon', 'cassandra-schmidt', 'luke-pepper', 'mark-milton',
#        'stephen-brown', 'andrea-leek', 'anthony-mountney',
#        'jeff-englebrecht', 'dean-grass', 'steve-richards', 'todd-howlett',
#        'leon-macdonald', 'darrell-burnet', 'jack-van-duren',
#        'david-j-smith', 'jamie-stewart', 'grant-jobson', 'aaron-laing',
#        'adrian-mcgregor', 'gwenda-johnstone', 'john-salanitri',
#        'todd-smart', 'kurt-goldman', 'matthew-kelley', 'nick-olive',
#        'brett-scott', 'edward-orourke', 'george-osborne',
#        'rachael-cunningham', 'lauri-parker', 'cathleen-wilson',
#        'tom-button', 'wendy-kelly', 'luke-cerchi', 'tara-vigouroux',
#        'josh-julius', 'hanna-powell', 'aiden-st-vincent',
#        'mark-stephenson', 'daniel-robinson', 'patrick-keane',
#        'tetyana-furdetska', 'dominika-griglakova', 'robert-price',
#        'lyn-shand', 'jim-conlan', 'joe-cleary', 'daniel-morton',
#        'lucy-keegan-attard', 'mark-jones', 'katrina-alexander-nz',
#        'cliff-brown', 'luke-fernie', 'mitchell-kearney', 'adam-chambers',
#        'melanie-ogorman', 'pat-farrell', 'kerry-weir', 'colin-scott',
#        'stephen-farley', 'ken-kelso-nz', 'andrew-ryan', 'kylie-kennedy',
#        'colt-prosser', 'mitchell-leek', 'scott-collings',
#        'holly-mckechnie', 'jarrod-austin', 'peter-burgun',
#        'michael-hickmott', 'rodger-waters', 'dan-mccarthy',
#        'gordon-richards', 'sean-casey', 'mick-sell', 'andrew-macdonald',
#        'rod-symons', 'andrew-dale', 'paul-anthony-jones', 'kacy-fogden',
#        'julien-welsh', 'lou-luciani', 'charlotte-littlefield',
#        'michael-mulholland', 'matthew-williams', 'david-matts',
#        'shannon-g-hope', 'tim-martin', 'quinton-scott', 'lucy-longmire',
#        'shilleagh-meyervale', 'nick-harnett', 'peter-jolly',
#        'stephen-schofield', 'george-dimitropoulos', 'joseph-burges',
#        'phil-sweeney', 'paul-rocke', 'gary-moore', 'jan-wicks',
#        'vincent-malady', 'shane-jackson', 'luke-morgan', 'drew-tyson',
#        'reece-goodwin', 'thomas-carberry', 'stephen-lee', 'stephen-field',
#        'lou-mary', 'shane-stockdale', 'mike-van-gestel',
#        'peter-w-stanley', 'travis-doudle', 'michelle-ritchie',
#        'donna-scott', 'clint-lundholm', 'denim-wynen', 'chris-heywood',
#        'michelle-fleming', 'cameron-thompson', 'sean-mott',
#        'ryan-balfour', 'terry-evans', 'matthew-robinson',
#        'jim-wallace-nz', 'daiki-chujo', 'michael-oleary',
#        'darryn-weatherley-nz', 'mark-gee', 'justin-bowen',
#        'stirling-osland', 'lance-noble-nz', 'grant-finnigan',
#        'john-bannister', 'glenn-cross', 'peter-hardacre', 'tyrone-coyle',
#        'robert-heathcote', 'barry-baldwin', 'mick-attard', 'sigrid-carr',
#        'mick-smith', 'michelle-payne', 'scott-mcintosh', 'steve-wolfe',
#        'noel-watson', 'peter-h-bloomfield', 'michael-lunn',
#        'brett-partelle', 'richard-collett', 'con-karakatsanis',
#        'lisa-jones', 'ray-besanko', 'scott-spackman', 'paddy-payne',
#        'craig-martin', 'lee-creek', 'kym-hann', 'michael-trotter',
#        'michael-mehegan', 'bruce-wallace-nz', 'wayne-carroll',
#        'tim-mcintosh', 'kelvin-bourke', 'geoffrey-crothers',
#        'tammy-birnie', 'tony-sergi', 'shane-oxlade', 'david-blundell',
#        'peter-sinclair', 'michael-templeton', 'michael-krikas',
#        'steven-wilson', 'cassandra-stummer', 'toby-pracey', 'pat-cannon',
#        'mark-cross', 'brett-conlon', 'deanne-taylor', 'andrew-campbell',
#        'brendon-hawtin', 'terry-kelly', 'rob-blacker', 'amanda-turner',
#        'craig-blackshaw', 'nathan-hobson', 'steven-king', 'con-kelly',
#        'chris-munce', 'grant-dalziel', 'sharyn-trolove', 'gerard-moloney',
#        'glen-milligan', 'wayne-hudd', 'brett-dodson', 'john-blacker',
#        'mark-mason', 'kerry-taplin', 'david-oprey', 'luke-clarke',
#        'marc-chevalier', 'oopy-macgillivray', 'michael-morrison',
#        'yassy-nishitani', 'donna-gaskin', 'chris-hyland', 'graham-payne',
#        'shane-bottomley', 'jonny-field', 'denis-pagan',
#        'bill-papazaharoudakis', 'yoshito-yahagi-jpn', 'steven-wise',
#        'peter-blanch', 'matthew-lindsay', 'david-vandyke',
#        'stuart-warden', 'steve-cunningham', 'guy-lowry-nz',
#        'lucinda-boyd', 'cheryl-grouse', 'julie-scott', 'emma-fouchard',
#        'john-price', 'sterling-alexiou', 'geon-singh',
#        'simon-crisford-gb', 'warren-gavenlock', 'colin-hughes',
#        'tom-wilson'], dtype=object)

# %%
pd.DataFrame(df_trainer).to_csv('/Users/phillipmonk/research_paper/horse_code/data/trainers.csv')
