# %%
# Assert minimum versions 
import sys 
assert sys.version_info >= (3, 5) 
import sklearn 
assert sklearn.__version__ >= "0.20" 
 
# Import packages and modules that will be used 
import numpy as np 
import pandas as pd
from sklearn import linear_model
from sklearn import metrics 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import SGDClassifier 
from sklearn.metrics import accuracy_score 

# Import and configure matplotlib 
# %matplotlib inline  
import matplotlib as mpl  
import matplotlib.pyplot as plt 
mpl.rc('figure', dpi=120) # set good resolution

# Set a seed for reproducability
import random
random.seed(42)
# numpy needs a random seed, too
np.random.seed(42)

# %%
df = pd.read_csv('/Users/phillipmonk/research_paper/horse_code/data/horse_data.csv')

# %%
df.head()
# Out:
#     horse_name      foaled          colour      sire            dam      sex  \
# 0  A Good Yarn  18/09/2013  Brown or Black  O'lonhro  Little Thread  Gelding
# 1  A Good Yarn  18/09/2013  Brown or Black  O'lonhro  Little Thread  Gelding
# 2  A Good Yarn  18/09/2013  Brown or Black  O'lonhro  Little Thread  Gelding
# 3  A Good Yarn  18/09/2013  Brown or Black  O'lonhro  Little Thread  Gelding
# 4  A Good Yarn  18/09/2013  Brown or Black  O'lonhro  Little Thread  Gelding
#
#    group_1_wins  starts  firsts  seconds  ...  track_date  dist cond weight  \
# 0             0      46       6        8  ...    31/07/23  1100  9.0   61.5
# 1             0      46       6        8  ...    02/01/23  1125  3.0   54.0
# 2             0      46       6        8  ...    16/12/22  1109  3.0   61.5
# 3             0      46       6        8  ...    08/12/22  1100  3.0   58.5
# 4             0      46       6        8  ...    27/11/22  1000  4.0   56.5
#
#    800m  400m margin rating  odds odds_source
# 0   2.0   1.0   10.2     61  20.0          SP
# 1   7.0   5.0    6.7     61  11.0          SP
# 2   6.0   6.0    0.8     61   6.5          SP
# 3   4.0   5.0    1.0     61   9.5          SP
# 4  11.0  10.0    5.6     63  15.0          SP
#
# [5 rows x 39 columns]

# %%
df.head(10)
# Out:
#     horse_name      foaled          colour      sire            dam      sex  \
# 0  A Good Yarn  18/09/2013  Brown or Black  O'lonhro  Little Thread  Gelding
# 1  A Good Yarn  18/09/2013  Brown or Black  O'lonhro  Little Thread  Gelding
# 2  A Good Yarn  18/09/2013  Brown or Black  O'lonhro  Little Thread  Gelding
# 3  A Good Yarn  18/09/2013  Brown or Black  O'lonhro  Little Thread  Gelding
# 4  A Good Yarn  18/09/2013  Brown or Black  O'lonhro  Little Thread  Gelding
# 5  A Good Yarn  18/09/2013  Brown or Black  O'lonhro  Little Thread  Gelding
# 6  A Good Yarn  18/09/2013  Brown or Black  O'lonhro  Little Thread  Gelding
# 7  A Good Yarn  18/09/2013  Brown or Black  O'lonhro  Little Thread  Gelding
# 8  A Good Yarn  18/09/2013  Brown or Black  O'lonhro  Little Thread  Gelding
# 9  A Good Yarn  18/09/2013  Brown or Black  O'lonhro  Little Thread  Gelding
#
#    group_1_wins  starts  firsts  seconds  ...  track_date  dist  cond weight  \
# 0             0      46       6        8  ...    31/07/23  1100   9.0   61.5
# 1             0      46       6        8  ...    02/01/23  1125   3.0   54.0
# 2             0      46       6        8  ...    16/12/22  1109   3.0   61.5
# 3             0      46       6        8  ...    08/12/22  1100   3.0   58.5
# 4             0      46       6        8  ...    27/11/22  1000   4.0   56.5
# 5             0      46       6        8  ...    12/08/22  1130   8.0   58.0
# 6             0      46       6        8  ...    15/07/22  1100   7.0   55.5
# 7             0      46       6        8  ...    17/06/22  1125  10.0   58.5
# 8             0      46       6        8  ...    29/05/22  1100   5.0   57.5
# 9             0      46       6        8  ...    03/05/22  1100   6.0   58.5
#
#    800m  400m margin rating  odds odds_source
# 0   2.0   1.0   10.2     61  20.0          SP
# 1   7.0   5.0    6.7     61  11.0          SP
# 2   6.0   6.0    0.8     61   6.5          SP
# 3   4.0   5.0    1.0     61   9.5          SP
# 4  11.0  10.0    5.6     63  15.0          SP
# 5   6.0   4.0    5.1     64   7.5          SP
# 6   8.0   8.0    3.0     65  12.0          SP
# 7   3.0   3.0    0.8     65  11.0          SP
# 8  12.0  11.0    3.6     65  20.0          SP
# 9  12.0  12.0    0.1     65  41.0          SP
#
# [10 rows x 39 columns]

# %%
df_jockey = df['jockey'].unique()

df_jockey
# Out:
# array(['luke-williams', 'tom-madden', 'declan-bates', 'mikaela-lawrence',
#        'tayla-childs', 'will-price', 'jarrod-fry', 'damian-lane',
#        'luke-nolen', 'luke-campbell', 'matthew-chadwick', 'ryan-houston',
#        'paul-gatt', 'lachlan-overall', 'matthew-cartwright',
#        'dean-yendall', 'sheridan-clarke', 'daniel-stackhouse',
#        'alana-kelly', 'beau-mertens', 'kiran-quilty', 'craig-newitt',
#        'ben-melham', 'jye-mcneil', 'lachlan-king', 'sally-wynne',
#        'liam-riordan', 'dylan-turner', 'carleen-hefel', 'chris-mccarthy',
#        'sophie-logan', 'jake-toeroek', 'jake-duffy', 'winona-costin',
#        'patrick-moloney', 'michael-poy', 'barend-vorster',
#        'nash-rawiller', 'adam-hyeronimus', 'kerrin-mcevoy',
#        'joao-moreira-brz', 'brenton-avdulla', 'jamie-kah',
#        'craig-williams', 'jason-collett', 'hugh-bowman-hk',
#        'ashley-morgan', 'ben-looker', 'ben-allen', 'robbie-downey',
#        'jamie-mott', 'john-allen', 'blaike-mcdougall', 'thomas-stockdale',
#        'jackson-murphy', 'erin-molloy', 'nicole-seymour', 'jade-doolan',
#        'matthew-palmer', 'kirk-matheson', 'cejay-graham',
#        'jasper-franklin', 'rory-hutchings', 'bailey-wheeler',
#        'anna-roper', 'nick-heywood', 'jackson-searle', 'aaron-bullock',
#        'brandon-griffiths', 'chris-williams', 'celine-gaudray',
#        'grant-buckley', 'joshua-parr', 'christian-reith', 'william-pike',
#        'glyn-schofield', 'jeff-penza', 'clayton-gallagher', 'jake-noonan',
#        'linda-meech', 'ethan-brown', 'amy-mclucas', 'olivia-chambers',
#        'hannah-williams', 'michael-cahill', 'tommy-berry', 'rachel-king',
#        'dylan-gibbons', 'jay-ford', 'heavelon-van-der-hoven',
#        'reece-jones', 'louise-day', 'tim-clark', 'tom-sherry',
#        'koby-jennings', 'ryan-maloney', 'alysha-collett',
#        'james-innes-jnr', 'jaylah-kennedy', 'braidon-small',
#        'michael-dee', 'daniel-moor', 'arron-lynch', 'melissa-julius',
#        'brett-prebble', 'mitchell-aitken', 'jordan-childs',
#        'jacob-lowry-1', 'regan-bayliss', 'shaun-mckay', 'bridget-grylls',
#        'niranjan-parmar-nz', 'ryan-elliot-nz-1', 'ashvin-goindasamy-nz',
#        'andrew-adkins', 'chad-schofield', 'blake-shinn', 'andrew-gibbons',
#        'lee-magorrian', 'sam-clipperton', 'james-doyle-gb',
#        'callum-shepherd', 'tom-marquand-gb', 'jason-watson',
#        'ryan-moore-gb', 'ben-curtis-1', 'kieran-shoemark', 'tahlia-hope',
#        'joe-bowditch', 'brian-higgins', 'damien-thornton',
#        'alexandra-bryan', 'damien-oliver', 'emily-brown', 'dean-holland',
#        'greg-ryan', 'luke-rolls', 'benjamin-osmond', 'james-mcdonald',
#        'jamie-spencer-gb', 'joey-haynes', 'sean-levey-ire',
#        'josh-richards', 'codi-jordan', 'billy-egan', 'rhys-mcleod',
#        'alysha-warren', 'zac-spain', 'teo-nugent', 'jack-martin',
#        'jack-hill', 'fred-kersley', 'leith-innes-nz', 'luke-currie',
#        'matthew-cameron-nz', 'jason-holder', 'felicity-atkinson',
#        'anthony-darmanin', 'dom-tourneur', 'tyler-schiller',
#        'jett-stanley', 'ellen-hennessy', 'brodie-loy', 'keagan-latham',
#        'zac-wadick', 'jenny-duggan', 'michael-murphy', 'dan-mcgillivray',
#        'adam-sewell', 'jim-byrne', 'samantha-collett',
#        'campbell-rawiller', 'ben-price', 'todd-pannell',
#        'shane-foley-ire', 'gary-carroll-ire', 'samuel-payne',
#        'emily-finnegan', 'ellis-wong', 'lachlan-neindorf',
#        'kayla-crowther', 'margaret-collett', 'jessica-eaton',
#        'harry-coffey', 'brad-rawiller', 'laura-lafferty', 'corey-bayliss',
#        'jess-taylor', 'mitchell-bell', 'kathy-ohara',
#        'jean-van-overmeire', 'robbie-dolan', 'brock-ryan', 'zac-lloyd',
#        'karl-zechner', 'brandon-lerena', 'glen-boss', 'shaun-guymer',
#        'tegan-harrison', 'jeffrey-maund', 'james-orman', 'jordan-mallyon',
#        'larry-cassidy', 'ben-thompson', 'will-gordon-nz-1',
#        'josh-cartwright', 'jake-bayliss', 'boris-thornton',
#        'marnu-potgieter', 'logan-mcneil', 'lewis-german', 'harry-grace',
#        'mark-zahra', 'rob-hornby', 'oisin-murphy-gb', 'hector-crouch-gb',
#        'daniel-tudhope-gb', 'rossa-ryan-ire', 'harry-bentley-gb',
#        'william-buick-gb', 'cieren-fallon-gb', 'julia-presits',
#        'neil-farley', 'hannah-edgley', 'michael-walker', 'chris-caserta',
#        'brendon-mccoull', 'erica-byrne-burke', 'bulent-muhcu',
#        'brandon-louis', 'wiremu-pinn', 'johnathan-parkes-nz',
#        'joe-kamaruddin-nz', 'scott-pollard', 'luke-ferraris-chn',
#        'ryan-wiggins', 'noel-callow', 'nathan-day', 'jason-benbow',
#        'beany-panya', 'billy-owen', 'kayla-nisbet', 'baylee-nothdurft',
#        'mathew-cahill', 'jim-crowley-gb', 'andrea-atzeni-gb',
#        'jacob-opperman', 'sheriden-tomlinson', 'daniel-ganderton',
#        'damon-budler', 'patrick-scorse', 'madison-waters',
#        'jess-del-frari', 'michael-heagney', 'holly-durnan',
#        'michael-travers', 'jason-lyon', 'flavien-prat',
#        'christophe-soumillon-fr', 'robert-havlin-gb', 'alexandre-chesnau',
#        'chad-lever', 'emily-pozman', 'kyle-wilson-taylor', 'kody-nestor',
#        'madison-lloyd', 'tianni-chapman', 'jarrod-todd', 'quayde-krogh',
#        'chelsea-baker', 'sigrid-carr', 'jason-maskiell', 'teagan-voorham',
#        'kyle-maskiell', 'lisa-allpress-nz', 'sarah-macnab',
#        'zac-purton-hk', 'kozzi-asano-nz', 'michael-mcnab-nz',
#        'craig-zackey', 'craig-grylls-nz', 'masa-hashizume-nz',
#        'vinnie-colgan', 'ronald-simpson', 'georgina-mcdonnell',
#        'blake-spriggs', 'darryl-mclellan', 'danny-beasley', 'paul-denton',
#        'madeline-owen', 'brooke-stower', 'mark-du-plessis',
#        'john-keating', 'bruno-neto', 'john-robertson', 'madi-derrick',
#        'chelsea-hillier', 'camille-houlgatte', 'mikayla-weir',
#        'rachael-murray', 'jodi-worley', 'tatum-bull', 'fiona-sandkuhl',
#        'simon-miller', 'randy-tan', 'tom-prebble', 'makisha-salter',
#        'brian-park', 'zoe-hunt', 'braith-nock', 'stephen-mooney',
#        'jamie-powell-1', 'anthony-cavallo', 'eleanor-webster-hawes',
#        'james-reveley', 'clement-lecoeuvre-1', 'aaron-kuru', 'gary-lo',
#        'caitlin-jones', 'adrian-layt', 'richard-odonoghue',
#        'molly-bourke', 'david-egan-gb', 'jack-mitchell-gb',
#        'silvestre-de-sousa-gb', 'saffie-osborne', 'richard-kingscote-gb',
#        'mickael-barzalona', 'theo-bachelot-fr', 'stephanie-thornton',
#        'emily-atkinson', 'justin-huxtable', 'lachlan-scorse', 'joe-doyle',
#        'warren-kennedy-saf', 'opie-bosson-nz', 'frank-edwards',
#        'jade-darose', 'amy-herrmann', 'ross-osullivan', 'jack-virgona',
#        'benoit-de-la-sayette-1', 'maxime-guyon-fr', 'hugo-besnier',
#        'kevin-bohorun', 'luke-tarrant', 'jag-guthmann-chester',
#        'hannah-le-blanc', 'paul-hammersley', 'angela-jones',
#        'shayleigh-ingelse', 'raymond-spokes', 'andrew-mallyon',
#        'rose-hammond', 'tyson-barton', 'stacey-metcalfe',
#        'matthew-mcguren', 'micheal-hellyer', 'jai-williams',
#        'ruby-haylock', 'robbie-fradd', 'shane-crosse-ire',
#        'leeanne-mccoy', 'montanna-savva', 'nozi-tomizawa', 'jacob-golden',
#        'casey-waddell', 'gerald-mosse-hk', 'ioritz-mendizabal-fr',
#        'stephane-pasquier-fr', 'alana-livesey-1', 'callan-murray',
#        'christine-puls', 'craig-atkinson', 'nick-souquet', 'luke-dittman',
#        'patrick-mcdonald-ire', 'taylor-marshall', 'yvette-lewis',
#        'nick-keal', 'billy-cray', 'taiki-yanagida-nz',
#        'sam-weatherley-nz', 'danielle-johnson-nz', 'sairyn-fawke',
#        'daniel-northey', 'tom-ryan', 'brendan-ward',
#        'dylan-browne-mcmonagle', 'john-r-velazquez-usa', nan,
#        'trevor-whelan', 'colin-keane-ire', 'jaden-lloyd', 'ronan-whelan',
#        'paul-hamblin', 'sean-cormack', 'les-tilley', 'serg-lisnyy',
#        'darryl-horner-jnr', 'wendy-peel', 'robyn-freeman',
#        'steven-pateman', 'harry-cobden', 'jack-foley', 'ben-coen',
#        'chris-hayes-ire', 'william-lee-1', 'andrew-slattery',
#        'michael-sheehy', 'kate-hercock-nz', 'ryan-bishop', 'r-j-bishop',
#        'lynsey-satherley-nz', 'cory-parish', 'craig-robertson',
#        'andrew-calder', 'kelsey-lenton', 'angus-chung', 'michael-rodd',
#        'luke-dempsey-ire', 'aaron-mitchell', 'donnacha-obrien-ire',
#        'emmet-mcnamara', 'jamie-heffernan', 'michael-hussey-ire',
#        'coriah-keatings', 'deanne-panya', 'ron-stewart',
#        'cassey-williams', 'adam-mccabe', 'ryan-hurdle',
#        'pierre-charles-boudot-fr', 'chris-obrien', 'amelia-denby',
#        'sarah-field', 'suraj-narredu-ind', 'sarah-omalley-nz',
#        'rebecca-mcrae', 'richard-bensley', 'trudy-thornton-nz',
#        'jake-pracey-holmes', 'tom-eaves-gb', 'kevin-stott',
#        'adam-kirby-gb', 'vincent-ho-hk', 'karis-teetan-hk',
#        'sam-spratt-nz', 'erin-leighton', 'darren-danis-nz',
#        'hugo-journiac-fr', 'olivier-peslier', 'shanae-omeara',
#        'shirley-hunter', 'emily-lang', 'montana-philpot',
#        'tiffani-brooker', 'nikita-beriman', 'shane-kelly-gb',
#        'georgina-cartwright', 'william-stanley', 'luke-cartwright',
#        'justin-stanley', 'nathan-thomas', 'matthew-mcgillivray',
#        'anthony-allen', 'melea-castle', 'olivia-pickering',
#        'minonette-kennedy', 'wanderson-davila', 'nicole-vuille',
#        'kelly-gates', 'shannon-apthorpe', 'alisha-donald', 'adam-spinks',
#        'brendon-newport', 'frankie-dettori-gb', 'jackson-morris',
#        'robert-thompson', 'stephen-brown', 'matthew-poon-hk',
#        'anna-jordsjo', 'britney-wong', 'rochelle-milnes', 'dylan-stanley',
#        'jarrod-lorensini', 'william-mccarthy', 'emma-ly', 'aaron-sweeney',
#        'robbie-brewer', 'sam-ewing', 'jason-laking-nz',
#        'courtney-barnes-nz', 'jake-molloy', 'cobi-vitler',
#        'jayden-barrie', 'jake-barrett', 'ken-dunbar', 'angela-cooper',
#        'teaghan-martin', 'elissa-meredith', 'robert-tart-gb',
#        'gavin-lerena', 'luke-cumberland', 'rikki-jamieson',
#        'brooke-ainsworth', 'martin-dwyer', 'david-probert', 'paul-zerafa',
#        'tamsin-gough', 'john-kissick', 'matthew-bennett',
#        'scott-mccullagh', 'robert-colgan-ire', 'oisin-orr',
#        'clint-johnston-porter', 'brad-parnham', 'jarrad-noske',
#        'joseph-azzopardi', 'holly-watson', 'paul-harvey', 'jamie-powell',
#        'daniel-sheehy', 'dwayne-dunn', 'clayton-douglas', 'matthew-allen',
#        'dylan-caboche', 'lizzie-annells', 'samy-camacho', 'pablo-morales',
#        'antonio-gallardo', 'frank-alvarado-usa', 'kyle-frey',
#        'ruben-fuentes-usa', 'ben-robinson', 'ianish-luximon',
#        'adam-nicholls', 'wayne-davis', 'courtney-bellamy',
#        'ashley-butler', 'ray-dawson', 'alfred-chan',
#        'seamie-heffernan-ire', 'padraig-beggy', 'wayne-lordan-ire',
#        'dylan-bennett', 'noriyuki-masuda', 'danny-peisley',
#        'jamie-gibbons', 'mitch-stapleford', 'brad-pengelly',
#        'andrew-spinks', 'jake-hull', 'shaun-mcgruddy',
#        'rebecca-bronett-prag', 'steven-parnham', 'george-buckell',
#        'dane-oneill-gb', 'eoin-walsh', 'hollie-doyle',
#        'declan-mcdonogh-ire', 'lucinda-boyd', 'heidi-gillie',
#        'thomas-doyle', 'troy-baker', 'taylor-johnstone', 'david-pires',
#        'hazel-schofer-nz', 'rachel-shred', 'stephen-wilson',
#        'lacey-morrison', 'denicious-smith', 'chris-taylor',
#        'travis-wolfgram', 'lee-horner', 'jason-baldock', 'franny-norton',
#        'james-rogers', 'belinda-hodder', 'jonathan-riddell-nz',
#        'liam-blanch', 'hamish-mcneill-nz', 'mereana-hudson-nz',
#        'kacie-adams', 'kath-bell-pitomac', 'daniel-muscutt',
#        'neil-callan-gb', 'jasmine-cornish', 'scott-galloway',
#        'lani-allen', 'girish-goomany', 'beau-dene-appo', 'elione-chaves',
#        'simon-planque', 'donovan-dillon', 'rebecca-wilson',
#        'jason-hart-gb', 'connor-murtagh', 'donovan-yeo', 'kirk-stone',
#        'qin-yong', 'peter-graham', 'anaelle-gangotena',
#        'corey-campbell-nz', 'lee-callaway-nz', 'rochelle-wedrat-kroezen',
#        'warwick-satherley', 'nikki-olzard', 'damien-boutet-1',
#        'zara-lewis', 'gregory-benoist-fr', 'dakotah-keane',
#        'takeshi-yokoyama', 'benoit-de-la-sayette', 'stefano-cherchi',
#        'john-egan-ire', 'ashleigh-stanley', 'jason-waddell-nz',
#        'brad-stewart', 'dylan-dunn', 'stephen-donohoe', 'david-allan-gb',
#        'kevin-manning', 'nicole-currie', 'paul-hanagan',
#        'niall-mccullagh-ire', 'corey-sutherland', 'shayne-cahill',
#        'robert-beattie', 'jarrod-woodhouse', 'shane-s-arnold',
#        'jon-grisedale', 'terry-moseley', 'tina-comignaghi-nz',
#        'rohan-mudhoo', 'cameron-quilty', 'tamas-nagy-hun',
#        'stephen-baster', 'jackie-beriman', 'graham-kliese',
#        'marina-morel', 'pietro-romeo', 'jason-taylor', 'mikey-sheehy',
#        'jake-coen', 'keshaw-dhurun', 'ryan-bradley', 'daniel-small',
#        'juana-andreou', 'alice-lindsay', 'danica-munro', 'kelsey-hannan',
#        'georgie-catania', 'nicky-mackay-gb', 'steven-vella', 'neil-ryan',
#        'madeleine-wishart', 'martin-harley', 'pat-dobbs-gb',
#        'jordan-sanders', 'caitlin-king', 'nicholas-hyde',
#        'anthony-crastus', 'justin-potter', 'maddi-price', 'jade-doyle',
#        'laqdar-ramoly', 'vincent-cheminaud', 'cody-collis',
#        'tessa-townsend', 'chris-symons', 'tony-piccone',
#        'samantha-clenton', 'chris-whiteley', 'shaun-odonnell',
#        'neil-perryman', 'umberto-rispoli-fr', 'conor-mcgovern',
#        'leo-roussel', 'mark-pegus', 'chris-parnham', 'jason-brown',
#        'dakota-gillett', 'jean-bernard-eyquem', 'cristian-demuro-jpn',
#        'emma-lines', 'william-carver-gb', 'krysten-swaffer',
#        'george-wood-1', 'augustin-madamet', 'franck-blondel-fr',
#        'stephane-breux', 'harry-davies', 'paul-shiers', 'dylan-hogan',
#        'nathan-punch', 'matthew-l-chadwick-hk', 'derek-leung-hk',
#        'alex-badel', 'marco-ghiani', 'adrien-moreau', 'thomas-trullier',
#        'crystal-miette', 'breanna-bourke', 'gary-geran', 'akira-kajiya',
#        'sally-faulks', 'henderson-fernandes-brz', 'muriel-machado-brz',
#        'alan-kennedy', 'peter-hall', 'pat-cosgrave-1', 'isabella-teh',
#        'caitlin-tootell', 'carl-spry', 'keith-ballard', 'shae-nielson',
#        'jeffrey-felix', 'john-rudd', 'rory-cleary', 'chelsea-burdan-nz',
#        'gabrielle-semmens', 'vlad-duric', 'bailey-kinninmont',
#        'ronan-short', 'cassey-martinan', 'sonja-logan', 'kyra-yuill',
#        'chloe-azzopardi', 'joe-fanning-gb', 'oliver-stammers',
#        'charlie-bennett', 'jefferson-smith-1', 'brandon-may-nz',
#        'sanu-toolooa', 'savish-khetoo', 'hollie-hull', 'matthew-powell',
#        'chris-mciver', 'brooke-johnson', 'adam-farragher-gb',
#        'javier-castellano-usa', 'joel-rosario', 'trevor-mccarthy',
#        'hayley-turner-gb', 'jade-mcnaught', 'ava-catarino',
#        'natasha-faithfull', 'vad-bolozhinskyi', 'alexandre-gavilan',
#        'bailey-rogerson-nz', 'tayla-mitchell', 'crystal-lindsay',
#        'kavish-chowdhoory', 'samantha-wynne-nz', 'daryl-bradley-nz',
#        'mollie-fitzgerald', 'sean-davis', 'donagh-oconnor-ire',
#        'tahlia-fenlon', 'desiree-stra', 'jordan-turner',
#        'ronald-woodworth-sin', 'jessie-philpot', 'jade-hampson',
#        'caitlyn-munro', 'zoe-lloyd', 'ryan-tate', 'morgan-cole',
#        'luke-morris', 'adam-mcnamara', 'glen-colless', 'troy-turner',
#        'jason-whiting', 'peter-knuckey', 'luca-carboni',
#        'bauyrzhan-murzabayev', 'jan-verner', 'michal-abik',
#        'sibylle-vogt', 'adrie-de-vries', 'michael-cadeddu-ger',
#        'nathan-fazackerley', 'patrick-carbery', 'kate-walters',
#        'brayden-gaerth', 'john-powell', 'georgia-dobie-1', 'colin-lennon',
#        'jenna-edwards', 'bradley-vale', 'jerry-chau', 'keith-yeung',
#        'courtney-van-der-werf', 'selim-agbal', 'connor-beasley',
#        'joshua-bryan', 'teighan-worsnop', 'brooke-sweeney',
#        'lyle-hewitson', 'tayah-stalker', 'elen-nicholas',
#        'aurelien-lemaitre-fr', 'eran-boyd', 'kristo-sardelic',
#        'ismail-toker', 'stan-tsaikos', 'sophie-wilcock', 'kyle-hocking',
#        'scott-sheargold', 'gavin-ryan', 'pierre-louis-jamin',
#        'clifford-lee', 'bonnie-palise', 'lemmy-douglas', 'kristy-bennett',
#        'mitchell-pateman', 'charlotte-obeirne', 'faye-lazet-nz',
#        'stacey-callow', 'dougie-costello-gb', 'masayuki-abe',
#        'jorge-ricardo-brz', 'a-mota', 'wilkley-xavier-brz', 'peter-lui',
#        'bobby-el-issa', 'ace-lawson-carrol', 'vagner-borges',
#        'julien-auge-fr', 'shankar-muniandy-nz', 'jeff-kehoe',
#        'l-sutherland', 'leah-hemi', 'leigh-roche-ire', 'geoff-oloughlin',
#        'taj-dyson', 'simone-altieri', 'jerry-noske', 'renee-forrest',
#        'ryan-plumb', 'bonnie-thomson', 'zara-castellaz-faico',
#        'liv-odonnell', 'florent-geroux', 'mike-smith-usa',
#        'kent-desormeaux-usa', 'joe-bravo', 'shaun-bridgmohan-usa',
#        'hector-diaz-jnr', 'forest-boyce', 'morgan-butler', 'jamie-codd',
#        'nicola-currie', 'marvin-grandin', 'lukas-delozier-1',
#        'andrasch-starke-ger', 'chloe-wells', 'michelle-payne',
#        'sarah-robbins', 'josh-adams', 'remi-tremsal',
#        'yogesh-atchamah-nz', 'chris-johnson-nz', 'danielle-hirini-nz',
#        'leah-kilner', 'jackson-radley', 'brooke-hanham',
#        'antoine-hamelin', 'dale-smith', 'gregoire-legras',
#        'antonio-orani', 'irad-ortiz-jr', 'tony-hamilton-gb',
#        'barry-mchugh', 'louis-steward', 'martin-seidl-ger',
#        'andreas-helfenbein', 'henry-jaggard', 'lukas-delozier',
#        'claudio-colombi', 'rene-piechulek', 'kate-petersen',
#        'olivia-webb', 'jack-wong-hk', 'james-winks', 'nicolas-larenaudie',
#        'marie-melodie-pomarede', 'leigh-taylor', 'heni-ede',
#        'royston-ffrench-gb', 'rosie-myers-nz', 'grant-cooksley',
#        'kate-witten', 'chris-nicoll', 'craig-staples',
#        'cameron-lammas-nz', 'james-spencer', 'atsuya-nishimura-jpn',
#        'yusuke-fujioka-jpn', 'akihide-tsumura', 'yuga-kawada-jpn',
#        'mirai-iwata', 'yuichi-fukunaga-jpn', 'claudia-lions',
#        'gemma-steele', 'nathan-crosse', 'paul-mulrennan', 'kin-kwo-nz',
#        'fergus-gregory-gb', 'nathan-newton', 'simon-kok', 'joey-sheridan',
#        'adin-thompson', 'amy-graham', 'ronan-thomas-fr', 'v-t-mason',
#        'jasmine-fawcett-nz', 'krishna-mudhoo-nz', 'ryusei-sakai-jpn',
#        'yusaku-kokobun', 'akira-sugawara', 'yukito-ishikawa',
#        'kenji-kawamata', 'yasunari-iwata-jpn', 'kohei-matsuyama',
#        'mirco-demuro-ity', 'chris-dell', 'madan-singh-nz',
#        'liam-keniry-gb', 'tyler-leslight', 'dakota-graham',
#        'robert-faehr', 'paddy-harnett', 'shane-jackson', 'gosen-jogoo',
#        'daniel-bothamley-nz', 'coralie-pacaut-fr', 'brodie-kirby',
#        'charles-bishop', 'tegan-newman-nz', 'troy-harris'], dtype=object)

# %%
pd.DataFrame(df_jockey).to_csv('/Users/phillipmonk/research_paper/horse_code/data/jockeys.csv')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 pd.DataFrame(df_jockey).to_csv('/Users/phillipmonk/research_project/horse_code/data/jockeys.csv')
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/generic.py:3772, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3761 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3763 formatter = DataFrameFormatter(
#    3764     frame=df,
#    3765     header=header,
#    (...)
#    3769     decimal=decimal,
#    3770 )
# -> 3772 return DataFrameRenderer(formatter).to_csv(
#    3773     path_or_buf,
#    3774     lineterminator=lineterminator,
#    3775     sep=sep,
#    3776     encoding=encoding,
#    3777     errors=errors,
#    3778     compression=compression,
#    3779     quoting=quoting,
#    3780     columns=columns,
#    3781     index_label=index_label,
#    3782     mode=mode,
#    3783     chunksize=chunksize,
#    3784     quotechar=quotechar,
#    3785     date_format=date_format,
#    3786     doublequote=doublequote,
#    3787     escapechar=escapechar,
#    3788     storage_options=storage_options,
#    3789 )
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/io/formats/format.py:1186, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1165     created_buffer = False
#    1167 csv_formatter = CSVFormatter(
#    1168     path_or_buf=path_or_buf,
#    1169     lineterminator=lineterminator,
#    (...)
#    1184     formatter=self.fmt,
#    1185 )
# -> 1186 csv_formatter.save()
#    1188 if created_buffer:
#    1189     assert isinstance(path_or_buf, StringIO)
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/io/formats/csvs.py:240, in CSVFormatter.save(self)
#     236 """
#     237 Create the writer & save.
#     238 """
#     239 # apply compression and byte/text conversion
# --> 240 with get_handle(
#     241     self.filepath_or_buffer,
#     242     self.mode,
#     243     encoding=self.encoding,
#     244     errors=self.errors,
#     245     compression=self.compression,
#     246     storage_options=self.storage_options,
#     247 ) as handles:
#     248     # Note: self.encoding is irrelevant here
#     249     self.writer = csvlib.writer(
#     250         handles.handle,
#     251         lineterminator=self.lineterminator,
#    (...)
#     256         quotechar=self.quotechar,
#     257     )
#     259     self._save()
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/io/common.py:737, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     735 # Only for write methods
#     736 if "r" not in mode and is_path:
# --> 737     check_parent_directory(str(handle))
#     739 if compression:
#     740     if compression != "zstd":
#     741         # compression libraries do not like an explicit text-mode
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/io/common.py:600, in check_parent_directory(path)
#     598 parent = Path(path).parent
#     599 if not parent.is_dir():
# --> 600     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: '/Users/phillipmonk/research_project/horse_code/data'

# %%
df_trainer = df['trainer'].unique()

df_trainer

# %%
pd.DataFrame(df_trainer).to_csv('/Users/phillipmonk/research_paper/horse_code/data/trainers.csv')
